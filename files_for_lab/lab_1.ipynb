# %% [markdown]
# Some business Objectives:
#
# * Retain customers,
# * Analyze relevant customer data,
# * Develop focused customer retention programs.
#
# Based on the analysis, take targeted actions to increase profitable customer response, retention, and growth.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E64-A902
#
#  Directory of C:\Users\Admin\Documents\ironhack\Week_4\Day_1\Morning\lab-cleaning-numerical-data\files_for_lab
#
# 29-10-2022  16:25    <DIR>          .
# 29-10-2022  16:25    <DIR>          ..
# 24-10-2022  13:00    <DIR>          .ipynb_checkpoints
# 29-10-2022  16:25            47,539 lab_1.ipynb
# 24-10-2022  12:58         1,581,918 we_fn_use_c_marketing_customer_value_analysis.csv
#                2 File(s)      1,629,457 bytes
#                3 Dir(s)  13,498,163,200 bytes free

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the file
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
#display gathered data
def check_gathered_data(customer_df):
    #print('the shape')
    #customer_df.shape()
    print('data head')
    display(customer_df.head())
    print('the data types')
    display(customer_df.dtypes)
    print('data tail')
    display(customer_df.tail())
    print('data information')
    display(customer_df.info())

# %%
# coloumns to lower case and snake case
def convert_to_lower_snake_cases(customer_df):
    ## I tried the following method it did'nt work Unfortunately, so i used old method, by replacing everything manually. 
    #I would ask for your recomendation here
    #customer_df.columns.str.lower()
    #customer_df.columns = customer_df.columns.str.replace(' ', '_')
    #display(customer_df.head())
    #display(customer_df2.head())
    #return customer_df.columns
    customer_df.rename(columns={'Customer': 'customer', 'State': 'state', 'Customer_Lifetime_Value':'customer_lifetime_value','Response':'response','Coverage':'coverage','Education':'education','Effective_To_Date':'effective_to_date','EmploymentStatus':'employment_status','Gender':'gender','Income':'income','Location_Code':'location_code','Marital_Status':'marital_status','Monthly_Premium_Auto':'monthly_premium_auto','Months_Since_Last_Claim':'months_since_last_claim','Months_Since_Policy_Inception':'months_since_policy_inception','Number_of_Open_Complaints':'number_of_open_complaints','Number_of_Policies':'number_of_policies','Policy_Type':'policy_type','Policy':'policy','Renew_Offer_Type':'renew_offer_type','Sales_Channel':'sales_channel','Vehicle_Class':'vehicle_class','Vehicle_Size':'vehicle_size'}, inplace=True)

# %%
#Change effective to date column to datetime format.
def convert_to_datetime_format(customer_df):
    print('before formatting')
    display(customer_df.head())
    print(customer_df.dtypes)
    #customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], errors='coerce')
    #print('After formatting')
    #display(customer_df.head())
    #print(customer_df.dtypes)

# %%
# Check NaN values per column.
def check_missing(customer_df):
    customer_df.isna().sum()
    customer_df.columns[customer_df.isna().any()].tolist()
    
def check_null_values(customer_df):
    customer_df.isnull()

# %% [markdown]
# 7. Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
#discrete_list=[]
#continuous_list=[]
#categorical_list=[]

def data_type_check(customer_df):
    #    discrete = data.select_dtypes(include=['int64'])
    #    continuous = data.select_dtypes(include=['float64'])
    #    categorical = data.select_dtypes(object)

    discrete = customer_df.select_dtypes(include=['int64'])
    continuous = customer_df.select_dtypes(include=['float64'])
    categorical = customer_df.select_dtypes(object)
    return list(discrete),list(continuous),list(categorical)# returns discrete,continuous and categorical in this order  

    
discrete_list,continuous_list,categorical_list = data_type_check(customer_df)

# %% [markdown]
# 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it. **Hint**: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
#empty strings could be concerning in the categorical data
def find_empty_strings(customer_df):
    #categorical_list_df = customer_df[categorical_list]
    #categorical_list_df = customer_df[['customer','state','response','coverage','education','employment_status','gender','location_code','marital_status', 'policy_type','policy', 'renew_offer_type','sales_channel','vehicle_class','vehicle_size']]
    categorical_list_df = customer_df[['customer','state','response','coverage','education','employment_status','gender']]
    display(categorical_list_df.head())
    #display(np.where(categorical_list_df.applymap(lambda x: x == '')))
    categorical_list_df.fillna('U',inplace=True) # replace with an unknown value
    
    return customer_df

# %%
discrete_list=[]
continuous_list=[]
categorical_list=[]


check_gathered_data(customer_df)
convert_to_lower_snake_cases(customer_df)
convert_to_datetime_format(customer_df)
check_missing(customer_df)
check_null_values(customer_df)
data_type_check(customer_df)# discrete_list,continuous_list,categorical_list = data_type_check(customer_df) 
customer_df2 = find_empty_strings(customer_df)# identifies the empty strings in the category df

#we can use the following to create a library of this code too
#import numerical_data_cleaner etc..
# Out:
# data head
#   customer       state  Customer Lifetime Value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date employment_status gender  income  ...  \
# 0           2/24/11          Employed      F   56274  ...
# 1           1/31/11        Unemployed      F       0  ...
# 2           2/19/11          Employed      F   48767  ...
# 3           1/20/11        Unemployed      M       0  ...
# 4            2/3/11          Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
# Exporting this processed data to a csv
customer_df2.to_csv('we_fn_use_c_marketing_customer_value_analysis2 .csv')
