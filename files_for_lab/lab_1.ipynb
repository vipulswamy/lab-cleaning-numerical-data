# %% [markdown]
# Some business Objectives:
#
# * Retain customers,
# * Analyze relevant customer data,
# * Develop focused customer retention programs.
#
# Based on the analysis, take targeted actions to increase profitable customer response, retention, and growth.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1E64-A902
#
#  Directory of C:\Users\Admin\Documents\ironhack\Week_4\Day_1\Morning\lab-cleaning-numerical-data\files_for_lab
#
# 28-10-2022  00:38    <DIR>          .
# 28-10-2022  00:38    <DIR>          ..
# 24-10-2022  13:00    <DIR>          .ipynb_checkpoints
# 28-10-2022  00:38             5,011 lab_1.ipynb
# 24-10-2022  12:58         1,581,918 we_fn_use_c_marketing_customer_value_analysis.csv
#                2 File(s)      1,586,929 bytes
#                3 Dir(s)  15,239,868,416 bytes free

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the file
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
# Out:
#    Customer       State  Customer Lifetime Value Response  Coverage  \
# 0   BU79786  Washington              2763.519279       No     Basic
# 1   QZ44356     Arizona              6979.535903       No  Extended
# 2   AI49188      Nevada             12887.431650       No   Premium
# 3   WW63253  California              7645.861827       No     Basic
# 4   HB64268  Washington              2813.692575       No     Basic
# 5   OC83172      Oregon              8256.297800      Yes     Basic
# 6   XZ87318      Oregon              5380.898636      Yes     Basic
# 7   CF85061     Arizona              7216.100311       No   Premium
# 8   DY87989      Oregon             24127.504020      Yes     Basic
# 9   BQ94931      Oregon              7388.178085       No  Extended
# 10  SX51350  California              4738.992022       No     Basic
# 11  VQ65197  California              8197.197078       No     Basic
# 12  DP39365  California              8798.797003       No   Premium
# ...

# %%
#display gathered data
def check_gathered_data(customer_df):
    print('the shape')
    display(customer_df.shape())
    print('data head')
    display(customer_df.head())
    print('the data types')
    display(dcustomer_dfta.dtypes)
    print('data tail')
    display(customer_df.tail())
    print('data information')
    display(customer_df.info())

# %%
# coloumns to lower case and snake case
def convert_to_lower_snake_cases(customer_df):
    customer_df.columns.str.lower()
    customer_df.columns = customer_df.columns.str.replace(' ', '_')
    return customer_df.columns
# Out:
# Index(['Customer', 'State', 'Customer_Lifetime_Value', 'Response', 'Coverage',
#        'Education', 'Effective_To_Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location_Code', 'Marital_Status', 'Monthly_Premium_Auto',
#        'Months_Since_Last_Claim', 'Months_Since_Policy_Inception',
#        'Number_of_Open_Complaints', 'Number_of_Policies', 'Policy_Type',
#        'Policy', 'Renew_Offer_Type', 'Sales_Channel', 'Total_Claim_Amount',
#        'Vehicle_Class', 'Vehicle_Size'],
#       dtype='object')

# %%
#Change effective to date column to datetime format.
def convert_to_datetime_format(customer_df):
    customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'effective_to_date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Check NaN values per column.
def check_missing(customer_df):
    customer_df.isna().sum()
    customer_df.columns[data.isna().any()].tolist()
    
def check_null_values(customer_df):
    customer_df.isnull()

# %% [markdown]
# 7. Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
#discrete_list=[]
#continuous_list=[]
#categorical_list=[]

def data_type_check(customer_df):
    #    discrete = data.select_dtypes(include=['int64'])
    #    continuous = data.select_dtypes(include=['float64'])
    #    categorical = data.select_dtypes(object)

    discrete = customer_df.select_dtypes(include=['int64'])
    continuous = customer_df.select_dtypes(include=['float64'])
    categorical = customer_df.select_dtypes(object)
    return list(discrete),list(continuous),list(categorical)# returns discrete,continuous and categorical in this order  

    
discrete_list,continuous_list,categorical_list = data_type_check(customer_df)
# Out:
# ['Income',
#  'Monthly_Premium_Auto',
#  'Months_Since_Last_Claim',
#  'Months_Since_Policy_Inception',
#  'Number_of_Open_Complaints',
#  'Number_of_Policies']

# %% [markdown]
# 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it. **Hint**: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
#empty strings could be concerning in the categorical data
def find_empty_strings(customer_df):
    #categorical_list_df = customer_df[categorical_list]
    categorical_list_df = customer_df[['Customer','State','Response','Coverage','Education','Effective_To_Date','EmploymentStatus','Gender','Location_Code','Marital_Status', 'Policy_Type','Policy', 'Renew_Offer_Type','Sales_Channel','Vehicle_Class','Vehicle_Size']]
    display(np.where(categorical_list_df.applymap(lambda x: x == '')))
# Out:
#      Customer       State Response  Coverage Education Effective_To_Date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location_Code Marital_Status     Policy_Type  \
# ...

# %%
discrete_list=[]
continuous_list=[]
categorical_list=[]


check_gathered_data(customer_df)
convert_to_lower_snake_cases(customer_df)
convert_to_datetime_format(customer_df)
check_missing(customer_df)
check_null_values(customer_df)
data_type_check(customer_df)# discrete_list,continuous_list,categorical_list = data_type_check(customer_df) 
find_empty_strings(customer_df)# identifies the empty strings in the category df

#we can use the following to create a library of this code too
#import numerical_data_cleaner etc..
